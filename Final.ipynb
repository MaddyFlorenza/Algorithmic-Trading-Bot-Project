# %% [markdown]
# # NEFS Technology Division - Algorithmic Trading Project Template

# %% [markdown]
# ### Description
#
# As a group, you have been tasked with researching, implementing and testing a profitable Foreign Exchange (Forex) trading strategy. The pair you have been assigned is GBP/USD.
#
# Each group will have a number of Quants, Software Engineers and Product Managers. You will need to work as a team to allocate responsibilities for the duration of the project. e.g. a Product Manager may be incharge of setting up and maintaining the Jira backlog of tickets.
#
# You will be provided with a dataset that will allow you to develop and backtest your strategy. This dataset will provide you with all of the relevant data for a number of years. Your strategy will then be tested on a different timeframe to determine it's profitability (Profit/Loss).
#
# It may be useful to begin the task by trying to understand the 'bigger picture' of how each component of the project would come together i.e the strategy itself, the risk management system, the data and your testing systems.
#
# You will be provided with an initial template to set out the fundamental components of your system, but you can feel free to expand on these as you wish. However, you need to be wary that your strategy **MUST** still be able to be backtested through the function included below. Please **DO NOT** modify this function in any way.
#
# We have seperated your teams to include Analysts of different disciplines, skills and interests. You should capitalise on this to allow everyone to contribute to the project in the best way that they can.
#
# Some example roles you may want to have (you do not have to stick to these) :
#
# - Software Engineer
# - Quant Researcher
# - Quant Developer
# - Algo Engineer
# - Data Scientist
# - Product Manager
#
# Information Links:
#
# - [Investopedia - Forex Trading](https://www.investopedia.com/terms/f/foreign-exchange.asp)
# - [Investopedia - Forex (Definitions, How To and Examples)](https://www.investopedia.com/terms/f/forex.asp)
# - [CME Group British Pound GBP/USD Overview](https://www.cmegroup.com/markets/fx/g10/british-pound.html)
# - [Yahoo Finance GBP/USD Live Charts](https://finance.yahoo.com/quote/GBPUSD=X?p=GBPUSD=X&.tsrc=fin-srch)
# - [Yahoo Finance USD/GBP Live Charts](https://finance.yahoo.com/quote/GBP=X?p=GBP=X&.tsrc=fin-srch)
#
# #### Rules:
#
# Here are some rules to simplify this task.
#
# - You can only buy your positions in GBP and sell your positions in USD.
# - You can not leverage or borrow money to buy a position (no negative balances). If your wallet goes to 0 then something is wrong.
# - You can not sell a position you do not have (no shorting)
# - When selling a position, you must sell all of the lots within that position. You can not off-load part of your position.
#
#
# **What is a standard lot in Forex?**
#
# A standard lot in Forex is equal to **100,000 currency units**. It’s the standard unit size for traders, whether independent or institutional.
#
# If the GBP/USD exchange rate was $1.3000, one standard lot of the base currency (GBP) would be 130,000 units. This means, at the current price, you’d need 130,000 units of the quote currency (USD) to buy 100,000 units of GBP.
#
# ---

# %% [markdown]
# ### Datasets
#
# Under this section you will find that two initial datasets are being loaded to be used for this project. These datasets are:
#
# - GBP/USD Historical Prices between 01/01/2010 - 31/12/2020 (Daily)
# - USD/GBP Historical Prices between 01/01/2010 - 31/12/2020 (Daily)
#
# Through your research, you may also find that other datasets across the internet may prove useful in your strategy e.g. Geopolitical data, other currency pairs etc. Feel free to use such datasets to help improve your strategy if you would like to do so.

# %%
#importing some popular packages that you may find useful

from scipy.stats import norm
import numpy as np
import pandas as pd
import math
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from enum import Enum
from datetime import datetime
import uuid 
import string
from arch import arch_model

# %%
complete_gbp_usd_dataset = pd.read_csv('GBPUSD_2010_2022.csv')
complete_usd_gbp_dataset = pd.read_csv('USDGBP_2010_2022.csv')
complete_usd_gbp_dataset
# Out:
#             Date     Open     High       Low     Close  Adj Close  Volume
# 0     2010-01-01  0.61797  0.61992  0.617970  0.619850   0.619850     0.0
# 1     2010-01-04  0.61969  0.62247  0.615800  0.620590   0.620590     0.0
# 2     2010-01-05  0.62040  0.62617  0.618970  0.625360   0.625360     0.0
# 3     2010-01-06  0.62525  0.62720  0.622540  0.624070   0.624070     0.0
# 4     2010-01-07  0.62414  0.62890  0.622720  0.627590   0.627590     0.0
# ...          ...      ...      ...       ...       ...        ...     ...
# 2865  2020-12-25  0.73694  0.73990  0.734592  0.737898   0.737898     0.0
# 2866  2020-12-28  0.73672  0.74427  0.736500  0.736790   0.736790     0.0
# 2867  2020-12-29  0.74263  0.74284  0.739610  0.742610   0.742610     0.0
# 2868  2020-12-30  0.74087  0.74104  0.734350  0.740746   0.740746     0.0
# 2869  2020-12-31  0.73368  0.73479  0.730750  0.733640   0.733640     0.0
#
# [2870 rows x 7 columns]

# %% [markdown]
# ## Signal

# %%
data_ori = pd.DataFrame(complete_gbp_usd_dataset)
# if you havent installed the library (talib) then run the following code (remove the three dots )
'''
url = 'https://launchpad.net/~mario-mariomedina/+archive/ubuntu/talib/+files'
ext = '0.4.0-oneiric1_amd64.deb -qO'
# !wget $url/libta-lib0_$ext libta.deb
# !wget $url/ta-lib0-dev_$ext ta.deb
# !dpkg -i libta.deb ta.deb
# !pip install ta-lib
'''

####################################################################################################

import talib as tal
signal = 0
sum_signal = [0]*21

data_ori["RSI"] = tal.RSI(data_ori["Open"], timeperiod=14)

# Initialize signal
signal = 0

# Loop over data
for i in range(21, len(data_ori)):
    signal = 0
    # Check RSI condition
    if data_ori["RSI"][i] < 30:
        rsi_condition = True
    elif data_ori["RSI"][i] > 70:
        rsi_condition = False
    else:
        rsi_condition = False
        
    # Generate signal if both conditions are met
    if rsi_condition == True: 
        signal += 1
    if rsi_condition == False:
        signal +=-1
    else: 
        signal +=0
    sum_signal.append(signal)

data_ori['Signal_macd'] = ((sum_signal))

# %%
#try the interest rate formula with close price
#complete_usd_gbp_dataset = pd.DataFrame(pd.read_csv('GBPUSD_2010_2022.csv'))
ppp = pd.DataFrame(pd.read_csv('PPP.csv'))
uk_ppp = (ppp['United Kingdom'])
us_ppp = (ppp['United States'])

gbp_usd_ppp = pd.DataFrame({'ppp':uk_ppp/us_ppp, 'date':ppp['Country Name']})
sig = []
gbp_usd_ppp['date'] = pd.to_datetime(gbp_usd_ppp['date'], format='%Y')
gbp_usd_ppp['date']= gbp_usd_ppp['date'].dt.strftime('%Y-%m-%d')
gbp_usd_ppp['date']= pd.to_datetime(gbp_usd_ppp['date'], format='%Y-%m-%d')
start_date = pd.Timestamp('31/12/2009') + pd.DateOffset(day=31)
end_date = pd.Timestamp('01/02/2023') + pd.DateOffset(day=31)
dates = pd.date_range(start_date, end_date, freq='D')
dates.name = 'date'
gbp_usd_ppp.set_index('date', inplace=True)

gbp_usd_ppp = gbp_usd_ppp.reindex(dates, method='ffill')
gbp_usd_ppp.reset_index(inplace=True)
gbp_usd_ppp.rename(columns={'index': 'date'}, inplace=True)


sig=[]
price = (data_ori['Open'])
for i in range(0,len(testtttt)):
    if gbp_usd_ppp['ppp'][i]<(1/price[i]):
        sig.append(1)
    elif gbp_usd_ppp['ppp'][i]>(1/price[i]):
        sig.append(-1)
    else:
        sig.append(0)
data_ori['Signal_ppp'] = sig

# %%
data = pd.DataFrame(complete_gbp_usd_dataset)

data['returns'] = data['Open'].pct_change()
data['returns'].dropna()

dates = data['Date']

y = 100*data['returns'].dropna()   #note this still has the n/a term
# adding new column
data['pc_returns'] = 100*data['returns'].dropna()
data['pc_returns'].fillna(0, inplace=True)
# forecasting vol
rolling_predictions = []
test_size = len(data_ori)-1
 # new class for dates
for i in range(test_size):

    train = data['pc_returns'].iloc[:-(test_size - i)]
    model = arch_model(train, p=2, q=0)
    model_fit = model.fit(disp='off')
    pred = model_fit.forecast(horizon=1, reindex=True)
    rolling_predictions.append(np.sqrt(pred.variance.values[-1, :][0]))

rolling_predictions = pd.Series(rolling_predictions, index=y.index)
data['vol_forecast'] = rolling_predictions
sig = [0]*2

for i in range(0,len(data['vol_forecast'])):
    if data['vol_forecast'][i]> 0.75:
        sig.append(1)
    elif data['vol_forecast'][i]<=0.75:
        sig.append(-1)

data_ori['Sig'] = sig
# Out:
# /Users/chunhimyeung/opt/anaconda3/lib/python3.8/site-packages/arch/univariate/volatility.py:1189: RuntimeWarning: invalid value encountered in double_scalars
#   scale = np.mean(resids**2) / (target ** (2.0 / power))
# /Users/chunhimyeung/opt/anaconda3/lib/python3.8/site-packages/arch/univariate/base.py:753: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /Users/chunhimyeung/opt/anaconda3/lib/python3.8/site-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.01926. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/chunhimyeung/opt/anaconda3/lib/python3.8/site-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.01297. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/chunhimyeung/opt/anaconda3/lib/python3.8/site-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08774. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(

# %% [markdown]
# ### Portfolio
#
# Under this section you will find the boiler plate code for this task. This includes a class named 'portfolio' which will house key data around your trades such as your budget (monetary portfolio), net profit/loss, current positions and number of trades executed etc.
#
# Each time you run a backtest of your strategy, this object will be reinstatiated and repopulated with the latest backtest results.
#
# You **MUST NOT** modify this code in any way. If you suspect there is a bug, please let Ahmed know and he will look into resolving it.

# %% [markdown]
# ## All of the backend code. DO NOT CHANGE THIS SECTION IN ANY WAY.

# %%
INITIAL_WALLET_CASH = 5000000
STANDARD_LOT = 100000

class Side(Enum):
    BUY = 'BUY'
    SELL = 'SELL'
    
class Currency(Enum):
    GBP = 'GBP'
    USD = 'USD'
    
class Position:
    def __init__(self,
                 date:datetime,
                 size:int,
                 price,
                 currency:Currency,
                 side:Side):
        
        self._id = str(uuid.uuid4())
        self._date = date
        self._currency = currency
        self._price = price
        self._size = size
        self._side = side
        
class Order:
    def __init__(self,
                 position:Position):
        self._id = str(uuid.uuid4())
        self._position = position
    
    def describe(self):
        return f"<Order id: {self._id} position: {self._position}>"

class Portfolio:
    
    def __init__(self):
        self.cash_wallet = INITIAL_WALLET_CASH  # wallet is in GBP
        self.current_positions = {}
        self.closed_positions = {}
    
    def add_position(self,position):
        self.current_positions[position._id] = position
        self.deduct_from_wallet(self.calculate_deduction(position))
                
    def sell_position(self,position:Position):
        self.current_positions.pop(position._id)
        self.closed_positions[position._id] = position
    
    def get_wallet_value(self):
        return self.cash_wallet
    
    def deduct_from_wallet(self,amount):
        self.cash_wallet -= amount
        
    def add_to_wallet(self,amount):
        self.cash_wallet += amount
        
    def calculate_fees(self,position:Position):
        fee = position._size * 2 #broker fee is £2 per standard lot 
        print("FEE CHARGED: £",fee)
        return fee 
    
    def calculate_total_cost_in_gbp(self,position:Position):
        if(position._currency == Currency.GBP):
            return position._price * (position._size * STANDARD_LOT)
        # elif(position._currency == Currency.USD):
        #     return position._price * current_gbp_price  * (position._size * 100000) # x100000 for standard lot

    def calculate_deduction(self,position):
        return self.calculate_total_cost_in_gbp(position) + self.calculate_fees(position)

# %% [markdown]
# ## You can edit from this point onwards

# %%
## You can implement your strategy in this function.
## Feel free to create additional functions and call them from within the 'strategy' function
## As show in the example below, your function must return a dictionary of orders. 
## These orders will be run through the backtesting function
def strategy(data):
    
    FIXED_LOT_SIZE = 1
    
    orders = {}
    
    for index,row in data.iterrows():
        
        if(row["Sig"]>0) or (row['Signal_macd'] >0) or (row['Signal_ppp']>0):
            
            date = datetime.strptime(str(row["Date"]),'%Y-%m-%d').date()
            
            #if we have money available in the wallet, we can buy
            buy_position = Position(date,FIXED_LOT_SIZE,row.Open,Currency.GBP,Side.BUY)
            buy_order = Order(buy_position)
            orders[buy_order._id] = buy_order
    
        if(row["Sig"] <=0) or (row['Signal_macd'] <=0) or (row['Signal_ppp']<=0):
            date = datetime.strptime(str(row["Date"]),'%Y-%m-%d').date()
            sell_position = Position(date,FIXED_LOT_SIZE,row.Open,Currency.GBP,Side.SELL)
            sell_order = Order(sell_position)
            orders[sell_order._id] = sell_order
   
    return orders

# %%
# You can use this function to backtest your strategy 
# The function will call your strategy and then execute the orders in the sequence you made them
# Once all of your orders have been completed, you will be shown your final wallet amount and your Profit/Loss.
def local_backtest_strategy(data):
    
    # Initialising the portfolio. £5,000,000 cash and no positions. 
    portfolio = Portfolio()
    order_queue = strategy(data) #calls your function to get all of the orders
    
    for index,order in order_queue.items():
    
        if(order._position._side == Side.BUY):
            # if you have enough cash, you can make the purchase 
            if portfolio.calculate_total_cost_in_gbp(order._position) <= portfolio.cash_wallet:
                portfolio.add_position(order._position)
                print(f"BUY ORDER FILLED : (ID) {str(order._id).upper()}")
            else: 
                print("BOOK CASH IS INSUFFICIENT")
                
        if(order._position._side == Side.SELL):
            # finding the position we want to sell from our current positions within portfolio
            matching_position  = next((position for position in portfolio.current_positions.values()
                                   if position._side == Side.BUY 
                                   and position._size == order._position._size 
                                   and position._price < order._position._price
                                   and position._date < order._position._date)
                                   ,None)
            
            if(matching_position != None):
                sale_earning = order._position._price * (order._position._size * STANDARD_LOT) 
                portfolio.add_to_wallet(sale_earning)
                portfolio.sell_position(matching_position)
                print(f"SELL ORDER FILLED : (ID) {str(order._id).upper()}")
            else:
                print("NO MATCHING POSITION FOUND")
    
    print("ALL ORDERS HAVE BEEN FILLED.")
    print("BOOK CASH LEVEL:", ("£%.2f" % portfolio.cash_wallet))
    
    pnl = portfolio.cash_wallet - INITIAL_WALLET_CASH 
    
    if(pnl < 0):
        print("TOTAL LOSS",("£%.2f" % abs(pnl)))
    else:
        print("TOTAL PROFIT",("£%.2f" % pnl))

local_backtest_strategy(data)
# Out:
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 138A82A4-9B8C-4F4E-B820-C7D1678E120E
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) D160D68C-8D40-4298-8383-FCD175FDC8D0
# NO MATCHING POSITION FOUND
# SELL ORDER FILLED : (ID) 3604E2D6-FD09-440F-9460-F68BF464B683
# SELL ORDER FILLED : (ID) F491364B-8C15-4AAD-8734-FBEF51264474
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 7A8462D5-3563-475C-A9E6-D37A45BF72A5
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) CB8CE306-EEE2-4F99-A445-CC6C28E22A6E
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) E5E0D41B-2799-4806-B0CD-FD868EC84E24
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) E942996C-D869-4E3E-859E-150B3E524492
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 91C1E1AC-279C-4CB5-9489-288867CD79C4
# SELL ORDER FILLED : (ID) 882C3810-688D-464D-B5E3-FED01C8C5A94
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 8E34546B-1F39-4172-89C9-0F8ECBA7CC96
# SELL ORDER FILLED : (ID) A9E57DFC-6E21-4C67-91C9-1FDBC1CAE3FB
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 749AFC4D-899F-4D37-BCD8-13EEE2018FF2
# NO MATCHING POSITION FOUND
# SELL ORDER FILLED : (ID) C19FF49A-1719-4BB3-800F-0EC5D6F21DE4
# SELL ORDER FILLED : (ID) AF0838CA-F794-45F4-8B12-34AE73C1466F
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# SELL ORDER FILLED : (ID) 35A127FF-D7FA-43C2-BCD8-3E0A3770CCE4
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# SELL ORDER FILLED : (ID) 0F1408F3-84B0-4A4C-87B2-43C8CDC41C9F
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 8C2CCF9C-D9D6-419A-99C0-32BE4109F8FE
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 93D3017F-5AD2-445E-9AB0-B2E9183BB991
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# SELL ORDER FILLED : (ID) 296ACF06-DA69-465A-9019-8FB51382B0A3
# NO MATCHING POSITION FOUND
# SELL ORDER FILLED : (ID) 42D4F954-AB31-49DC-AC02-7B324FC5AA30
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 9C6A2433-6FDE-4728-AA5D-C7E48E4AF7E9
# NO MATCHING POSITION FOUND
# SELL ORDER FILLED : (ID) E50BE73C-8483-4ACF-AE9C-0464BB405331
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 421ED7C2-F004-4F4A-A220-D8071C258D18
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 029F409A-2A42-4923-B3ED-7697CB8BB45E
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 65D4065E-1A72-4F64-A4D8-2E01E0474290
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 45577FD5-DEF2-49A4-A5CB-1412E36EE90B
# SELL ORDER FILLED : (ID) A1840032-A97F-4175-8C7A-8B9F434118DC
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) A609B875-EC4B-46F1-BCE8-DC5AD1E48908
# NO MATCHING POSITION FOUND
# SELL ORDER FILLED : (ID) 2B7F1F0F-3BE9-401C-BD9C-D23D5615C8CF
# SELL ORDER FILLED : (ID) 879AD4BD-97C9-409E-B749-1EC8ABB8E39B
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# SELL ORDER FILLED : (ID) EEAD59FD-FC50-425A-89F9-5A39323C38F5
# NO MATCHING POSITION FOUND
# SELL ORDER FILLED : (ID) 3E8B520B-0EFD-4444-B783-320D776EC8AD
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# SELL ORDER FILLED : (ID) 1258E03D-183C-4EAA-A8AC-6E9E202E36A5
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) CEF1955F-8ED1-4D69-8567-C48B0FC58E31
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) BAF93DDA-BF59-4A5F-A67D-FD394879095A
# SELL ORDER FILLED : (ID) D8B30A91-18FF-41FA-ABDD-83AC46E8118C
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) F70AE72C-82C2-4EF4-928F-20F5FD2CCB19
# SELL ORDER FILLED : (ID) 37469852-E343-4C90-87DF-E64FCCF6A79C
# ...
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 39E904CE-0428-4987-BA13-4B67EF850881
# SELL ORDER FILLED : (ID) 24C852E9-F7B4-4D6B-AC9E-BD2490F9EFA5
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) BB81D66C-A90A-41B8-BFD1-6F290E0493F5
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 089898E4-14DA-4916-A298-339859E3DA51
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 5B7C40DF-A44C-475E-B919-6F5E091E67CF
# SELL ORDER FILLED : (ID) 6BD05252-F6A6-46C1-AE4B-9E5B89C1FA2E
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) D7F97BDD-182F-42A9-8EAD-8E87CA4F8DB0
# SELL ORDER FILLED : (ID) E87A037F-59E4-45D5-A2BF-41073CFF5F5C
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 24DAA00F-0DD0-4204-8712-BB18C665FB44
# SELL ORDER FILLED : (ID) 50FD5E36-714F-4F14-9909-A9F846CAD710
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) A528E753-31A2-4961-8BF4-74871DC96600
# SELL ORDER FILLED : (ID) 8F03CFA6-8293-48C1-8C6F-E427BB48029F
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 38F0975E-18F9-4F65-A38C-B8656826D891
# SELL ORDER FILLED : (ID) AD4C6862-096A-4982-92D8-7122D099C182
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 772572EF-F387-4834-B9CD-88A02D259759
# SELL ORDER FILLED : (ID) 2B2A6068-5EA0-42B9-AC27-0BBDF2C12E48
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 988493B2-982D-430F-8508-A1C661B4D3F2
# SELL ORDER FILLED : (ID) 5911177A-CFFB-4123-8870-6ADB336A072E
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 5DA272DD-2834-457F-99D8-393D4A528ADE
# SELL ORDER FILLED : (ID) E207C86E-D7B9-44F1-967F-2FB2126BEF91
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) C67FAD56-A29F-4682-B6B4-A3CEB2B2200B
# SELL ORDER FILLED : (ID) B64DCCDA-DDA0-4B4A-96F1-AF75B6874CFF
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 54CD2339-D736-4711-BBFD-80B3A0061EBD
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 1E8B78DD-D801-4743-A9BF-C5E8670FA86C
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 278CD348-445D-4C39-B0E1-D69C6EC23590
# SELL ORDER FILLED : (ID) 86FD188E-B402-4237-9999-400A2BB2CAAB
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 9020808B-D080-4794-8F2C-78236303BD55
# SELL ORDER FILLED : (ID) F684EE3B-8139-41A4-87DC-514520A4D038
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 9AB24887-CFE3-4F5A-9FAB-58DEE963D67D
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) A5D7FA3D-BD35-4598-9761-1A87E513043D
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 9402DABF-3821-43C9-928C-BFF961D2A1C9
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 27908DE1-176D-4CFE-AF91-E17D90467E3E
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 7A74652F-082C-4F36-80E5-E1F9F2063DFD
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 89195459-157C-4811-8B31-4C496DA48127
# SELL ORDER FILLED : (ID) F5377E6B-E573-4743-960E-50CB87D7002D
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) F517D486-AF3F-4A16-A084-B0257199E450
# SELL ORDER FILLED : (ID) 681DD8DD-DFF4-4C12-AF23-E2160908F399
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 6575BD00-1A52-423A-826C-80148338592F
# SELL ORDER FILLED : (ID) 7BEE53CE-F276-4F4F-8DAD-FCEC620B3A8E
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) BEB8CA88-FE0C-4A41-A592-599B2BC1544F
# SELL ORDER FILLED : (ID) 6DDC8578-0E05-4A82-949D-B816CB383A8F
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) B92A5CC6-D9A6-4246-A70D-243D0A4A34BD
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) CEEA8781-5E31-4CCA-AEED-C5A82D95064C
# SELL ORDER FILLED : (ID) FF5587D5-EC67-4B84-9D81-6FAAB9C9D1A4
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) EDAAF994-7415-4F70-9D87-97940A5F3792
# SELL ORDER FILLED : (ID) 7C40CB87-6622-442A-83D4-08F94B157B76
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) D7FAA121-37BC-4E03-8E27-6D3A9410FE6F
# SELL ORDER FILLED : (ID) 1A906AB1-DC9C-4A28-8D30-6DF7FEF4931D
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) D717BF1B-C2F6-49E3-9453-23B930646FFE
# SELL ORDER FILLED : (ID) 2EF0DB1D-BD1C-4A58-8636-A7F70227D5A9
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 61151B61-680D-41C4-9B5E-68B0B828B32E
# SELL ORDER FILLED : (ID) 81704EB3-EB3F-4059-AB70-D1887E42955A
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 2D298DBC-56B5-4991-A365-4DD4D2147B2E
# SELL ORDER FILLED : (ID) CAE854CB-C730-4742-8884-FACF105B9F24
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) B73BDCFA-62D8-406E-8CC0-45720C5DF3CF
# SELL ORDER FILLED : (ID) 1324D730-0A89-4033-BD8D-15D74BDA15BE
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 8AF992C4-48F4-4025-B4BD-6E1345424B05
# SELL ORDER FILLED : (ID) 1BA8E005-FD2F-4051-80AF-365604FA9945
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) F827725C-59B5-4EE1-B62C-DB93D45CB8E5
# SELL ORDER FILLED : (ID) 19D40E8A-0E6A-424A-B359-29BCC8BC4B42
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 931CFC23-E7FC-4AE4-8C10-F1AF81CC0A9D
# SELL ORDER FILLED : (ID) 425C2AC0-8908-4EF4-987E-BF75002DAD56
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 69C488C9-ADBC-4D5A-A171-8E169F3ABAEC
# SELL ORDER FILLED : (ID) 2C96B188-9B3C-4CC7-BFB9-5D35030EE96A
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) E153BB15-03A7-43B9-8CB9-600C4D6847D0
# SELL ORDER FILLED : (ID) 4913CAD3-8962-4F80-85A5-37B20F611DEF
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) D79FD9A3-9445-4C66-9404-CEC48711CEEF
# SELL ORDER FILLED : (ID) C890A1D5-21FF-4AB7-AFA1-C990B7576DFD
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 04036792-89FA-44B5-AF9A-A88B4DCEA270
# SELL ORDER FILLED : (ID) 66224AD1-7E45-4657-8482-C53E90484447
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) AD4912A9-3911-455A-A36E-C9DE8793DE5B
# SELL ORDER FILLED : (ID) BD05C16C-68A7-408D-B04F-4BCC885D4570
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 38BBCA3B-5199-4452-BE06-7B36B07B0D27
# SELL ORDER FILLED : (ID) 7750610A-EE1B-4938-A3B4-4EBE0F8039EB
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 0D9DFB30-CDF2-4159-AD98-2233EB11C5C7
# SELL ORDER FILLED : (ID) CCFE8780-882D-4DC3-836C-A54A8568331A
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) F511587F-4F4A-405D-BB0B-4068A2B19B3D
# SELL ORDER FILLED : (ID) BEC5DBBE-CC20-42A5-983D-AD7F22DD9C50
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 59AC28CF-2170-41FF-921C-934F902327C3
# SELL ORDER FILLED : (ID) 7DFB9E92-5D97-4056-9F00-E5269338E6D9
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 594F271A-EDE3-4973-AADA-D2C9647B45B2
# SELL ORDER FILLED : (ID) A99029CD-BC8F-4621-B501-C176146090A8
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 8AAB1E4D-C70E-4EC9-BDE4-1FC177DD88B7
# SELL ORDER FILLED : (ID) C9434BCD-46F5-43DC-907D-DA4E91E9E5D0
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 8F15D8DB-3560-4B5D-A711-62747A43E6AC
# SELL ORDER FILLED : (ID) 4AE1437A-2A46-4B15-88D1-18D87DF704BC
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 81941516-10F5-4B7E-BF94-5AA9B7644C1A
# SELL ORDER FILLED : (ID) C6A3ECF9-5AC4-48A0-AED0-8388909453C9
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 1DE157DD-3FF6-4CAC-B1B0-68D90AFCCD09
# SELL ORDER FILLED : (ID) FB1EE560-2D07-44DC-B2B7-0BEE0B1B8347
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 2B791DBA-791D-44B2-BC5C-53ECAB21464F
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 7E9A321B-A0E3-40C4-BBEA-A4C4D7F1F459
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) B790271E-9F96-4551-A604-3CF617CF9B4A
# SELL ORDER FILLED : (ID) F1D7B4AB-1E7D-4835-9E62-01946DE68571
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) C8BB34A7-066F-4A70-BE03-B5F7D28ACAD1
# SELL ORDER FILLED : (ID) B356B41F-162D-43FB-8153-F0B65C63AC9B
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 30AE61AD-F42E-4B8E-BEF9-F0C776ED0A52
# SELL ORDER FILLED : (ID) 675AA17B-D86B-4F46-AED1-4C09E9193786
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 56401047-EA60-4C75-95E6-C5D9E0F0885B
# SELL ORDER FILLED : (ID) DD90C53C-7EB5-43B3-B820-49CB1311C3A0
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) EB5283FB-33EF-41B4-85B4-0CEACB0162A5
# SELL ORDER FILLED : (ID) 3F6F1859-1837-4934-ACE6-51CF3992F9D6
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 90D55D54-3391-4765-9A0A-F601BAFAC120
# SELL ORDER FILLED : (ID) FE50943B-6E5A-42EE-930A-829D74B25AF1
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) C4B71579-1353-4421-B085-3B976675D3F1
# SELL ORDER FILLED : (ID) 48267BE8-F0A2-4E51-9E11-5F4B766B29D1
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 0CFB8D8A-1B3B-4CE7-9F42-FFF8E5CCFDC5
# SELL ORDER FILLED : (ID) B062439F-1EEB-4B64-A7AA-52664343A389
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 9C1E3078-CDDA-4703-8114-EB130D93874F
# SELL ORDER FILLED : (ID) C0B68019-273F-48B9-8CDF-120A338E52AC
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 34DC037A-61BA-4982-9259-820DEFCD43E6
# SELL ORDER FILLED : (ID) B1581CE3-424E-4F7D-925C-128400203AE1
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 1FC06702-9F3D-40FF-8763-3AA98C581AA7
# SELL ORDER FILLED : (ID) 2DFB2813-AE91-49B1-BE10-69A1C3349470
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 9E3EAE7C-82E6-4869-8B63-4DE1385C4F67
# SELL ORDER FILLED : (ID) 2D6FCE60-9FC6-49D4-ABD2-0C3DEFCD74E3
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 1430FC98-381E-47FE-90FC-36A65D1C4CC4
# SELL ORDER FILLED : (ID) 5590A7C7-9317-4152-9055-D0ADD74A69EF
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 4AF937E4-140D-4033-B57D-1D66892C7B1B
# SELL ORDER FILLED : (ID) CE65CE42-C8CF-493A-BEFB-5499EAA463FC
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 4FA3A61A-1FBF-4C4B-80A4-02448F7DF2D0
# SELL ORDER FILLED : (ID) AF500E67-AFBB-448A-82C4-F6337905F3F9
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 7BA95EC2-5618-4DF0-826D-6074ED6B2220
# SELL ORDER FILLED : (ID) 5D6FCDFA-8AF8-4C4D-AD2D-277FEF5161EA
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) DE3527D0-D6CD-4916-A6B8-321C633EC0B6
# SELL ORDER FILLED : (ID) D2050DC2-3774-437C-B104-1870525580BA
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 94D31698-F4A4-4229-BB53-82076CBEC091
# SELL ORDER FILLED : (ID) 85FC47C2-9E01-4EA8-BDF2-3787AA6B46EC
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) FB77B1C8-686D-4D03-A0FA-C66433E6FF9D
# SELL ORDER FILLED : (ID) B0A1F0D4-DEB5-4A55-AC98-BBAF2A064A8D
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 10C1675A-1C82-4ED9-8335-76390D6A81FC
# SELL ORDER FILLED : (ID) 64762337-B73C-4EA6-B0A3-776B8B04BF5C
# SELL ORDER FILLED : (ID) D71CAB63-DE93-4FEA-8719-FAE74ACC71D1
# SELL ORDER FILLED : (ID) DFF70F67-20F0-4009-A02F-DCF0A9D620A4
# SELL ORDER FILLED : (ID) 3D72ABE0-C2C2-491F-A25D-D449E69D3FAA
# SELL ORDER FILLED : (ID) 385911A9-98CB-40C5-801D-0DC5D9742FEC
# SELL ORDER FILLED : (ID) 10438649-CFB2-483D-95CB-6B257D6D0C3D
# SELL ORDER FILLED : (ID) F4C519AA-E2BE-463D-82F9-7D1065B39A34
# SELL ORDER FILLED : (ID) F0EEE109-DC51-4867-AB00-D5935755A905
# SELL ORDER FILLED : (ID) 0226CDAB-AE4A-452C-8FB0-9523D22D499D
# SELL ORDER FILLED : (ID) 2F362C3E-7D7C-4294-BBB3-9E373098444B
# SELL ORDER FILLED : (ID) 12D648D0-03F8-4178-896E-8DEE13C63DDE
# SELL ORDER FILLED : (ID) B111024A-7FC8-4879-9A7A-36CA0BF436C6
# SELL ORDER FILLED : (ID) B9DA07FF-55EB-4375-99FA-F2BF1C0E3652
# SELL ORDER FILLED : (ID) CF93D6AF-3467-438F-B9FB-0629EFA3F1BE
# SELL ORDER FILLED : (ID) EBEBB4FE-0B84-4FEE-AF7E-51C2A9509C63
# SELL ORDER FILLED : (ID) 72E1DE82-F235-4C3C-A4CB-368160098D5D
# SELL ORDER FILLED : (ID) B0A4A47B-6906-408E-9D96-D1B9939E1B01
# SELL ORDER FILLED : (ID) 46412A57-B6F1-47E9-864F-9D0FBE93617D
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 2EC6DEBB-E5A4-4006-B693-97CEBDD13571
# SELL ORDER FILLED : (ID) 4B7BC7C9-12FE-4526-872D-5306335AD230
# SELL ORDER FILLED : (ID) 42BFE4F4-4A03-4FF4-B509-E87004C7DAC8
# SELL ORDER FILLED : (ID) 9E5E5025-16FC-4700-8DB1-B0E4AB60A131
# SELL ORDER FILLED : (ID) D177750F-987E-4B51-9F79-1C72594671EA
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# SELL ORDER FILLED : (ID) AC5F62AE-36A1-4ACF-9529-5ED2A824197C
# SELL ORDER FILLED : (ID) BEE007F9-CCF8-4EF3-9945-549B8E55752F
# SELL ORDER FILLED : (ID) 6C6BBE5D-A3B4-49D0-9D5B-FA78BE6D6177
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) BF235FF4-7096-4058-9FF9-8F72604693FE
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 6731FDBE-21E0-44A5-B191-B5C35F761A05
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 75108FF5-799A-4274-ACE5-59ED74FB1AF8
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 7CADDCE1-DF30-406E-9E43-D50F56F121CE
# SELL ORDER FILLED : (ID) B5968B72-9E8C-4CAF-89D4-8EBBE483A71F
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 7FA7B6C2-AF90-4B88-A984-D811FE4072D4
# SELL ORDER FILLED : (ID) 5F2439B2-E8A0-4C23-9E5B-3841EE21F532
# SELL ORDER FILLED : (ID) BC2C662C-A766-45A7-81F6-B8BAF2714B45
# SELL ORDER FILLED : (ID) EB642AF3-EF6C-49D2-B5B4-B8F92D3E61CD
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 452F76F7-8F0A-468A-A526-8E473313425F
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) B5163209-54B0-42FE-8395-BCA7C4DFEF4C
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) F6A9FCF0-FCD6-4354-AC43-B224467FE8DF
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 1E02DE19-E3D0-424A-AEE8-39802CCF37A7
# SELL ORDER FILLED : (ID) 1F6BD1B6-1193-4B5D-BEFC-2B5202B2B246
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 3BAA35E6-7820-49EE-907B-76D6BBBE3FF7
# SELL ORDER FILLED : (ID) 377DF00A-D028-4FCB-9037-DF910E72A03F
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 42C9E826-73D0-4C76-AC91-8715A987DDAA
# SELL ORDER FILLED : (ID) 6E09A8CF-61AC-4DBF-A72A-54B005365F78
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 20D0F78B-02F8-4AB0-8644-4EB65FA1AA79
# SELL ORDER FILLED : (ID) 431D4F4A-9760-4C26-B23C-21F260A2A954
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) FB77BE31-521D-4798-AC1E-FCA0FA1E8134
# SELL ORDER FILLED : (ID) E29AD98B-7444-464F-9FDE-A8337F6F477D
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 74788354-170D-4973-810A-767CAE0E476E
# SELL ORDER FILLED : (ID) 42BA1F22-DC49-4C35-A9B1-DE36AD0C727B
# SELL ORDER FILLED : (ID) 4020DC4C-B462-470A-81FB-58188A3F35E0
# SELL ORDER FILLED : (ID) 8C8B25C0-A112-4D14-B381-D3B1BF122634
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 06C53218-AECC-47D1-9EF6-1B1EDF198C67
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 51127180-EFFA-4871-A8CD-740F35CD39E4
# SELL ORDER FILLED : (ID) 2D96DAE3-371A-4760-9A1E-F819E8AEF02E
# SELL ORDER FILLED : (ID) B46B0D63-18C9-47AB-BEE2-6F2F2C5CC333
# SELL ORDER FILLED : (ID) C69B0AB5-0E6E-4996-8FE2-F03F71C84097
# SELL ORDER FILLED : (ID) EABB7B20-84A8-43CB-80F7-9AB1F69D9513
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) D1074CCD-BAC4-4AE3-BBE4-8C983D499BFB
# NO MATCHING POSITION FOUND
# SELL ORDER FILLED : (ID) C3C6525C-97A4-4FEB-B3A3-EDC18D42C709
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 8B1DCF28-8AF7-4790-BF99-10803F24C488
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 2251575B-E82C-45BA-A0D6-697159C10B14
# SELL ORDER FILLED : (ID) 7ABDF538-2003-47FC-8612-1D20FD9AF09B
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 30035828-72DC-406B-89B6-1C1F2179173E
# SELL ORDER FILLED : (ID) D0F81FA4-A199-40F1-A758-60691A86BD18
# NO MATCHING POSITION FOUND
# SELL ORDER FILLED : (ID) 110A644B-9B71-4B3F-8F6D-AB7CAC5542FF
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# ALL ORDERS HAVE BEEN FILLED.
# BOOK CASH LEVEL: £5962674.20
# TOTAL PROFIT £962674.20

# %% [markdown]
# ## Data Analysis and Research
#
# You can include all of your data analysis and research under this section. Maybe some cool charts and formulas too? Next time.

# %% [markdown]
# ## Risk Management
#
# You can include your risk management process and functions (code) under this section.

# %%
def risk_manager():
    pass
